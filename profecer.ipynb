# %%
from func import *
import matplotlib.pyplot as plt
from tensorflow import summary as sm
from tensorflow import keras
from keras import models, layers, optimizers
from keras.callbacks import ModelCheckpoint
import datetime
import os
from keras.layers import BatchNormalization,Dropout

# %%
# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   # 텐서플로가 첫 번째 GPU에 1GB 메모리만 할당하도록 제한
#   try:
#     tf.config.experimental.set_virtual_device_configuration(
#         gpus[0],
#         [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=8240)])
#   except RuntimeError as e:
#     # 프로그램 시작시에 가상 장치가 설정되어야만 합니다
#     print(e)

# %%
VERSION = 'propecer'

FILE_01 = 'DST_80.csv'
FILE_00 = 'FUDS_80.csv'
FILE_02 = 'US06_80.csv'
drop_labels_x = ['Data_Point', 'Test_Time(s)', 'Date_Time', 'Step_Time(s)', 'Step_Index', 'Cycle_Index', 'Charge_Capacity(Ah)', 'Discharge_Capacity(Ah)', 'Charge_Energy(Wh)'\
                 , 'Discharge_Energy(Wh)', 'AC_Impedance(Ohm)','SoC(%)','dV/dt(V/s)','ACI_Phase_Angle(Deg)',]
drop_labels_y = ['Data_Point', 'Test_Time(s)', 'Date_Time', 'Step_Time(s)', 'Step_Index', 'Cycle_Index', 'Charge_Capacity(Ah)', 'Current(A)', 'Discharge_Capacity(Ah)', 'Charge_Energy(Wh)', \
                 'Discharge_Energy(Wh)', 'dV/dt(V/s)', 'AC_Impedance(Ohm)','ACI_Phase_Angle(Deg)','Voltage(V)','Have_Capacity(Ah)']

param = {'seq_len' : 300, 'num_units' : 150, 'num_units2' : 16, 'num_filters' : 128, 'window' : 5, 'dropout': 0.2, 'num_epochs' : 2000, 'num_dense': 80, 'batch':1024}
Fsize=3

log_dir = f"logs/{VERSION}/" + datetime.datetime.now().strftime("%Y%m%d-%H%M") + f'-{param["num_epochs"]}'
file_path = f'weight\{VERSION}\SOH_Checkpoint\{param["num_epochs"]}\{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}.h5'
hist_freq = 250

save_path = f'picture\{VERSION}\{Fsize}\{param["num_epochs"]}EP'
try:
    if not os.path.exists(save_path):
        os.makedirs(save_path)
except OSError:
    print('Error Creating Directory...')

# %%
data00, data_cap00 = get_data(FILE_00, drop_labels_x, drop_labels_y)
data01, data_cap01 = get_data(FILE_01, drop_labels_x, drop_labels_y)
data_test, data_cap_test = get_data(FILE_02, drop_labels_x, drop_labels_y)
#FUDS
A1 = data00[2604:]
A2 = data_cap00[2604:]
#DST
B1 = data01[1933:]
B2 = data_cap01[1933:]
#US06
C1 = data_test[1271:]
C2 = data_cap_test[1271:]

data00 = A1 
data_cap00 = A2
data01 = B1
data_cap01 = B2
data_test = B1
data_cap_test = B2


print(f'data00 = {data00.shape}')
pl.plot(data00)
pl.show()
print(f'data01 = {data01.shape}')
pl.plot(data_cap00)
pl.show()
print(f'data02 = {data_test.shape}')
pl.plot(data_cap_test)
pl.show()
savedata00 =  data00
savedata_cap00 =  data_cap00
savedata01 =  data01
savedata_cap01 =  data_cap01
savedata_test = data_test
savedata_cap_test = data_cap_test
# Out:
# Index(['Voltage(V)', 'Have_Capacity(Ah)'], dtype='object')
# Index(['SoC(%)'], dtype='object')
# Index(['Voltage(V)', 'Have_Capacity(Ah)'], dtype='object')
# Index(['SoC(%)'], dtype='object')
# Index(['Voltage(V)', 'Have_Capacity(Ah)'], dtype='object')
# Index(['SoC(%)'], dtype='object')
# data00 = (11077, 2)
# data01 = (10625, 2)
# data02 = (10625, 2)

# %%
#1/n 필터
data00 = lowpass1(data00, Fsize)[Fsize:]
data_cap00 = lowpass1(data_cap00,Fsize)[Fsize:]
data01 = lowpass1(data01,Fsize)[Fsize:]
data_cap01 = lowpass1(data_cap01,Fsize)[Fsize:]
data_test = lowpass1(data_test,Fsize)[Fsize:]
data_cap_test = lowpass1(data_cap_test,Fsize)[Fsize:]

size=(int)(savedata00.shape[0]-Fsize/2)
size1=(int)(savedata01.shape[0]-Fsize/2)
size2=(int)(savedata_test.shape[0]-Fsize/2)
Edata00 =  savedata00[Fsize:size]-data00
Edata_cap00 =  savedata_cap00[Fsize:size]-data_cap00
Edata01 =  savedata01[Fsize:size1]-data01
Edata_cap01 =  savedata_cap01[Fsize:size1]-data_cap01
Edata_test = savedata_test[Fsize:size2]-data_test
Edata_cap_test = savedata_cap_test[Fsize:size2]-data_cap_test

# %%
# #1/n 필터 뒤
# data00 = lowpass(data00, Fsize)[Fsize:]
# data_cap00 = lowpass(data_cap00,Fsize)[Fsize:]
# data01 = lowpass(data01,Fsize)[Fsize:]
# data_cap01 = lowpass(data_cap01,Fsize)[Fsize:]
# data_test = lowpass(data_test,Fsize)[Fsize:]
# data_cap_test = lowpass(data_cap_test,Fsize)[Fsize:]

# Edata00 =  savedata00[Fsize:]-data00
# Edata_cap00 =  savedata_cap00[Fsize:]-data_cap00
# Edata01 =  savedata01[Fsize:]-data01
# Edata_cap01 =  savedata_cap01[Fsize:]-data_cap01
# Edata_test = savedata_test[Fsize:]-data_test
# Edata_cap_test = savedata_cap_test[Fsize:]-data_cap_test
# print(f'data00 = {data00.shape}')
# print(f'Edata00 = {Edata00.shape}')
# pl.plot(Edata_test)
# pl.show()

# %%
# #3 필터계수 (0.25 0.5 0.25)
# data00 = lowpass2(data00 )[1:]
# data_cap00 = lowpass2(data_cap00)[1:]
# data01 = lowpass2(data01)[1:]
# data_cap01 = lowpass2(data_cap01)[1:]
# data_test = lowpass2(data_test)[1:]
# data_cap_test = lowpass2(data_cap_test)[1:]

# size=(int)(savedata00.shape[0])
# Edata00 =  savedata00[1:size-1]-data00
# Edata_cap00 =  savedata_cap00[1:size-1]-data_cap00
# Edata01 =  savedata01[1:size-1]-data01
# Edata_cap01 =  savedata_cap01[1:size-1]-data_cap01
# Edata_test = savedata_test[1:size-1]-data_test
# Edata_cap_test = savedata_cap_test[1:size-1]-data_cap_test
# print(f'data00 = {data00.shape}')
# print(f'Edata00 = {Edata00.shape}')
# pl.plot(Edata_test)
# pl.show()

# %%
# #5 필터계수 (-0.125 0.25 0.75 0.25 -0.125)
# data00 = lowpass3(data00)[2:]
# data_cap00 = lowpass3(data_cap00)[2:]
# data01 = lowpass3(data01)[2:]
# data_cap01 = lowpass3(data_cap01)[2:]
# data_test = lowpass3(data_test)[2:]
# data_cap_test = lowpass3(data_cap_test)[2:]
# print(f'data00 = {data00.shape}')
# size=(int)(savedata00.shape[0])
# Edata00 =  savedata00[2:size-2]-data00
# Edata_cap00 =  savedata_cap00[2:size-2]-data_cap00
# Edata01 =  savedata01[2:size-2]-data01
# Edata_cap01 =  savedata_cap01[2:size-2]-data_cap01
# Edata_test = savedata_test[2:size-2]-data_test
# Edata_cap_test = savedata_cap_test[2:size-2]-data_cap_test

# print(f'Edata00 = {Edata00.shape}')
# pl.plot(Edata_test)
# pl.show()

# %%
# pl.figure(dpi=2500)
# pl.ylabel('Voltage')
# pl.xlabel('Time(s)')
# line = pl.plot(savedata_cap_test, label = 'Voltage Real')
# pl.setp(line, linewidth=0.3)

# y_line = pl.plot(data_cap_test, label = 'Voltage Low')
# # y_line = pl.plot(y_graph, label = 'Voltage Reference')
# pl.setp(y_line, linewidth=0.3)
# pl.legend()
# pl.savefig(f'{save_path}\Estimation.png')
# pl.show()

# %%
x_train00 = seq_gen_x(data00, param['seq_len'])
y_train00 = seq_gen_y(data_cap00, param['seq_len'])
x_train01 = seq_gen_x(data01, param['seq_len'])
y_train01 = seq_gen_y(data_cap01, param['seq_len'])
x_test = seq_gen_x(data_test, param['seq_len'])
y_test = seq_gen_y(data_cap_test, param['seq_len'])

plus=0

Ex_train00 = seq_gen_x(Edata00, param['seq_len'])+plus
Ey_train00 = seq_gen_y(Edata_cap00, param['seq_len'])+plus
Ex_train01 = seq_gen_x(Edata01, param['seq_len'])+plus
Ey_train01 = seq_gen_y(Edata_cap01, param['seq_len'])+plus
Ex_test = seq_gen_x(Edata_test, param['seq_len'])+plus
Ey_test = seq_gen_y(Edata_cap_test, param['seq_len'])+plus
print(x_train00.shape)
print(y_test.shape)
print(x_train00[0, 0:6, 1])
count=savedata_cap_test.shape[0]-y_test.shape[0]*y_test.shape[1]
print(count)
# Out:
# (10771, 300, 2)
# (10319, 1)
# [1.5993232 1.598762  1.5983151 1.5979342 1.5975106 1.597038 ]
# 306

# %%
from keras.optimizers import SGD
import tensorflow as tf
CosineAnnealing = tf.keras.optimizers.schedules.CosineDecay(1e-1, param['num_epochs'], 0.2) # 0.1
sgd=SGD(CosineAnnealing, momentum = 0.9)
# sgd=set_optimizer('SGD', 0.1, 2000)
# opt = keras.optimizers.Adamax(clipvalue=1.0,lr=0.001)

# %%
# sgd=set_optimizer('SGD', 0.1, 2000)
opt = keras.optimizers.Adamax(clipvalue=1.0,lr=0.001)
# Out:
# c:\Users\han\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\optimizer_v2\adamax.py:95: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adamax, self).__init__(name, **kwargs)

# %%
# model = models.Sequential()
# # model.add(layers.Conv1D(param['num_filters'], param['window'], padding='causal', input_shape = (None, x_train00.shape[-1])))
# model.add(layers.GRU(param['num_units'], return_sequences = True, input_shape = (None, x_train00.shape[-1])))
# # model.add(BatchNormalization())
# model.add(layers.SimpleRNN(param['num_dense']))
# # model.add(BatchNormalization())
# model.add(layers.Dense(1))
# model.compile(loss = 'mse', optimizer = opt) 
# model.summary()

# %%
model = models.Sequential()
# model.add(layers.Conv1D(param['num_filters'], param['window'], padding='causal', input_shape = (None, x_train00.shape[-1])))
model.add(layers.GRU(param['num_units'], return_sequences = True, input_shape = (None, x_train00.shape[-1])))
# model.add(BatchNormalization())
model.add(layers.SimpleRNN(param['num_dense']))
# model.add(BatchNormalization())
model.add(layers.Dense(1))
model.compile(loss = 'mse', optimizer = opt) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, None, 150)         69300
#
#  simple_rnn (SimpleRNN)      (None, 80)                18480
#
#  dense (Dense)               (None, 1)                 81
#
# =================================================================
# Total params: 87,861
# Trainable params: 87,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True)]
fitdata = model.fit(x_train00, y_train00, epochs=param['num_epochs'], verbose = 0, validation_split=0.01, callbacks=callback_list,batch_size=param['batch'])
callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True)]
fitdata = model.fit(x_train01, y_train01, epochs=param['num_epochs'], verbose = 0, validation_split=0.01, callbacks=callback_list,batch_size=param['batch'])

# %%
model.load_weights(file_path)
prediction = model.predict(x_test)

Lowprediction=prediction
# Out:
# 323/323 [==============================] - 14s 43ms/step

# %%
model = models.Sequential()
# model.add(layers.Conv1D(param['num_filters'], param['window'], padding='causal', input_shape = (None, x_train00.shape[-1])))
model.add(layers.GRU(param['num_units'], return_sequences = True, input_shape = (None, x_train00.shape[-1])))
# model.add(BatchNormalization())
model.add(layers.SimpleRNN(param['num_dense']))
# model.add(BatchNormalization())
model.add(layers.Dense(1))
model.compile(loss = 'mse', optimizer = opt) 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, None, 150)         69300
#
#  simple_rnn_1 (SimpleRNN)    (None, 80)                18480
#
#  dense_1 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 87,861
# Trainable params: 87,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True)]
fitdata = model.fit(Ex_train00, Ey_train00, epochs=param['num_epochs'], verbose = 1, validation_split=0.01, callbacks=callback_list,batch_size=param['batch'])
callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True)]
fitdata = model.fit(Ex_train01, Ey_train01, epochs=param['num_epochs'], verbose = 1, validation_split=0.01, callbacks=callback_list,batch_size=param['batch'])
# Out:
# Epoch 1/2000
# 11/11 [==============================] - 6s 390ms/step - loss: 2.7752e-04 - val_loss: 5.9766e-05
# Epoch 2/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 4.4782e-05 - val_loss: 5.1568e-05
# Epoch 3/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 2.1218e-05 - val_loss: 2.2787e-05
# Epoch 4/2000
# 11/11 [==============================] - 4s 365ms/step - loss: 1.2108e-05 - val_loss: 1.7848e-05
# Epoch 5/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 8.3510e-06 - val_loss: 1.2112e-05
# Epoch 6/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 6.3228e-06 - val_loss: 9.8631e-06
# Epoch 7/2000
# 11/11 [==============================] - 4s 347ms/step - loss: 5.2140e-06 - val_loss: 8.4294e-06
# Epoch 8/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 4.4393e-06 - val_loss: 7.4790e-06
# Epoch 9/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 3.9175e-06 - val_loss: 6.7906e-06
# Epoch 10/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 3.5594e-06 - val_loss: 6.3890e-06
# Epoch 11/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 3.2903e-06 - val_loss: 6.1138e-06
# Epoch 12/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 3.0835e-06 - val_loss: 5.8910e-06
# Epoch 13/2000
# 11/11 [==============================] - 4s 369ms/step - loss: 2.9226e-06 - val_loss: 5.7006e-06
# Epoch 14/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 2.7912e-06 - val_loss: 5.5207e-06
# Epoch 15/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 2.6653e-06 - val_loss: 5.3959e-06
# Epoch 16/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 2.5960e-06 - val_loss: 5.3610e-06
# Epoch 17/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 2.5383e-06 - val_loss: 5.3398e-06
# Epoch 18/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 2.4738e-06 - val_loss: 5.3405e-06
# Epoch 19/2000
# 11/11 [==============================] - 4s 366ms/step - loss: 2.4261e-06 - val_loss: 5.2401e-06
# Epoch 20/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 2.3315e-06 - val_loss: 5.1993e-06
# Epoch 21/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 2.2855e-06 - val_loss: 5.1381e-06
# Epoch 22/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 2.2618e-06 - val_loss: 5.2066e-06
# Epoch 23/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 2.2606e-06 - val_loss: 5.3776e-06
# Epoch 24/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 2.2401e-06 - val_loss: 5.1752e-06
# Epoch 25/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 2.1360e-06 - val_loss: 5.1788e-06
# Epoch 26/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 2.1211e-06 - val_loss: 5.1628e-06
# Epoch 27/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 2.0846e-06 - val_loss: 5.1754e-06
# Epoch 28/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 2.0627e-06 - val_loss: 5.1667e-06
# Epoch 29/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 2.0426e-06 - val_loss: 5.1610e-06
# Epoch 30/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 2.0492e-06 - val_loss: 5.2133e-06
# Epoch 31/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 2.0167e-06 - val_loss: 5.5641e-06
# Epoch 32/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 2.1036e-06 - val_loss: 5.3374e-06
# Epoch 33/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 2.0806e-06 - val_loss: 5.7686e-06
# Epoch 34/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 2.1468e-06 - val_loss: 5.3644e-06
# Epoch 35/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.9917e-06 - val_loss: 5.1561e-06
# Epoch 36/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.9221e-06 - val_loss: 5.1206e-06
# Epoch 37/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.8942e-06 - val_loss: 5.2088e-06
# Epoch 38/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.9616e-06 - val_loss: 5.2126e-06
# Epoch 39/2000
# 11/11 [==============================] - 4s 344ms/step - loss: 1.9546e-06 - val_loss: 5.3943e-06
# Epoch 40/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.9433e-06 - val_loss: 5.2189e-06
# Epoch 41/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.8828e-06 - val_loss: 5.2734e-06
# Epoch 42/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.8869e-06 - val_loss: 5.2125e-06
# Epoch 43/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.8552e-06 - val_loss: 5.2334e-06
# Epoch 44/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.8466e-06 - val_loss: 5.4040e-06
# Epoch 45/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.8316e-06 - val_loss: 5.2763e-06
# Epoch 46/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.8213e-06 - val_loss: 5.2653e-06
# Epoch 47/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.8215e-06 - val_loss: 5.2156e-06
# Epoch 48/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.8957e-06 - val_loss: 5.2508e-06
# Epoch 49/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.8095e-06 - val_loss: 5.2415e-06
# Epoch 50/2000
# 11/11 [==============================] - 4s 343ms/step - loss: 1.8151e-06 - val_loss: 5.2700e-06
# Epoch 51/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.7973e-06 - val_loss: 5.1892e-06
# Epoch 52/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.7768e-06 - val_loss: 5.2434e-06
# Epoch 53/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.7605e-06 - val_loss: 5.3014e-06
# Epoch 54/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.7810e-06 - val_loss: 5.1834e-06
# Epoch 55/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.7463e-06 - val_loss: 5.2490e-06
# Epoch 56/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.7275e-06 - val_loss: 5.2511e-06
# Epoch 57/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.7295e-06 - val_loss: 5.2486e-06
# Epoch 58/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.8016e-06 - val_loss: 5.2608e-06
# Epoch 59/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.7210e-06 - val_loss: 5.2094e-06
# Epoch 60/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.7069e-06 - val_loss: 5.2832e-06
# Epoch 61/2000
# 11/11 [==============================] - 4s 368ms/step - loss: 1.6995e-06 - val_loss: 5.2973e-06
# Epoch 62/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.6879e-06 - val_loss: 5.2962e-06
# Epoch 63/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.7154e-06 - val_loss: 5.4764e-06
# Epoch 64/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.7686e-06 - val_loss: 5.3139e-06
# Epoch 65/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.7233e-06 - val_loss: 5.3874e-06
# Epoch 66/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.9258e-06 - val_loss: 5.2693e-06
# Epoch 67/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.7568e-06 - val_loss: 5.2681e-06
# Epoch 68/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.8708e-06 - val_loss: 5.3549e-06
# Epoch 69/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.6966e-06 - val_loss: 5.4932e-06
# Epoch 70/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.7938e-06 - val_loss: 5.2665e-06
# Epoch 71/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.7272e-06 - val_loss: 5.5040e-06
# Epoch 72/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.7869e-06 - val_loss: 6.2625e-06
# Epoch 73/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 2.3564e-06 - val_loss: 5.4806e-06
# Epoch 74/2000
# 11/11 [==============================] - 4s 367ms/step - loss: 2.2216e-06 - val_loss: 5.5543e-06
# Epoch 75/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.7099e-06 - val_loss: 5.3387e-06
# Epoch 76/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.6614e-06 - val_loss: 5.5245e-06
# Epoch 77/2000
# 11/11 [==============================] - 4s 347ms/step - loss: 1.8684e-06 - val_loss: 5.3525e-06
# Epoch 78/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.8369e-06 - val_loss: 5.7245e-06
# Epoch 79/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 2.0146e-06 - val_loss: 5.7986e-06
# Epoch 80/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 2.1848e-06 - val_loss: 6.3546e-06
# Epoch 81/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.8172e-06 - val_loss: 5.5547e-06
# Epoch 82/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.6956e-06 - val_loss: 5.9406e-06
# Epoch 83/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.8688e-06 - val_loss: 5.7715e-06
# Epoch 84/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 2.1383e-06 - val_loss: 6.2310e-06
# Epoch 85/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 2.2409e-06 - val_loss: 5.4835e-06
# Epoch 86/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 2.1092e-06 - val_loss: 5.4760e-06
# Epoch 87/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 2.0616e-06 - val_loss: 6.1907e-06
# Epoch 88/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 2.1833e-06 - val_loss: 5.6835e-06
# Epoch 89/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 2.2283e-06 - val_loss: 5.4581e-06
# Epoch 90/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.9778e-06 - val_loss: 5.8324e-06
# Epoch 91/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.8460e-06 - val_loss: 5.6189e-06
# Epoch 92/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.8078e-06 - val_loss: 5.3642e-06
# Epoch 93/2000
# 11/11 [==============================] - 4s 366ms/step - loss: 1.6924e-06 - val_loss: 5.3183e-06
# Epoch 94/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.7203e-06 - val_loss: 5.9622e-06
# Epoch 95/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 2.2205e-06 - val_loss: 5.4905e-06
# Epoch 96/2000
# 11/11 [==============================] - 4s 377ms/step - loss: 1.7562e-06 - val_loss: 6.0129e-06
# Epoch 97/2000
# 11/11 [==============================] - 4s 365ms/step - loss: 2.1520e-06 - val_loss: 5.5335e-06
# Epoch 98/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.6265e-06 - val_loss: 5.3704e-06
# Epoch 99/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.6090e-06 - val_loss: 5.4180e-06
# Epoch 100/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.6773e-06 - val_loss: 5.3647e-06
# Epoch 101/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.7618e-06 - val_loss: 5.9199e-06
# Epoch 102/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.9308e-06 - val_loss: 6.1388e-06
# Epoch 103/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.8594e-06 - val_loss: 5.4111e-06
# Epoch 104/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.5889e-06 - val_loss: 5.3040e-06
# Epoch 105/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.6341e-06 - val_loss: 5.4802e-06
# Epoch 106/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.6505e-06 - val_loss: 5.4202e-06
# Epoch 107/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 4.8379e-06 - val_loss: 5.9698e-06
# Epoch 108/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 3.9088e-06 - val_loss: 7.2118e-06
# Epoch 109/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 2.0879e-06 - val_loss: 5.5385e-06
# Epoch 110/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.6440e-06 - val_loss: 5.2745e-06
# Epoch 111/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.7011e-06 - val_loss: 5.3762e-06
# Epoch 112/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.6624e-06 - val_loss: 5.2169e-06
# Epoch 113/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.6089e-06 - val_loss: 5.2057e-06
# Epoch 114/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.5897e-06 - val_loss: 5.2565e-06
# Epoch 115/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.5983e-06 - val_loss: 5.3032e-06
# Epoch 116/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.5897e-06 - val_loss: 5.2144e-06
# Epoch 117/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.6048e-06 - val_loss: 5.2662e-06
# Epoch 118/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.5674e-06 - val_loss: 5.2156e-06
# Epoch 119/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.5760e-06 - val_loss: 5.1797e-06
# Epoch 120/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.6930e-06 - val_loss: 5.2772e-06
# Epoch 121/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.5742e-06 - val_loss: 5.4569e-06
# Epoch 122/2000
# 11/11 [==============================] - 4s 366ms/step - loss: 1.5900e-06 - val_loss: 5.5986e-06
# Epoch 123/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.7970e-06 - val_loss: 5.2591e-06
# Epoch 124/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.7390e-06 - val_loss: 5.3115e-06
# Epoch 125/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.8778e-06 - val_loss: 5.3262e-06
# Epoch 126/2000
# 11/11 [==============================] - 4s 367ms/step - loss: 1.9994e-06 - val_loss: 5.3286e-06
# Epoch 127/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.9533e-06 - val_loss: 5.3364e-06
# Epoch 128/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.7721e-06 - val_loss: 5.2119e-06
# Epoch 129/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.7516e-06 - val_loss: 5.1664e-06
# Epoch 130/2000
# 11/11 [==============================] - 4s 368ms/step - loss: 1.7060e-06 - val_loss: 5.3418e-06
# Epoch 131/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.6172e-06 - val_loss: 5.5072e-06
# Epoch 132/2000
# 11/11 [==============================] - 4s 373ms/step - loss: 1.7505e-06 - val_loss: 5.6450e-06
# Epoch 133/2000
# 11/11 [==============================] - 4s 366ms/step - loss: 1.7215e-06 - val_loss: 5.2911e-06
# Epoch 134/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.6580e-06 - val_loss: 5.7226e-06
# Epoch 135/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.6601e-06 - val_loss: 5.2783e-06
# Epoch 136/2000
# 11/11 [==============================] - 4s 365ms/step - loss: 1.5684e-06 - val_loss: 5.0461e-06
# Epoch 137/2000
# 11/11 [==============================] - 4s 341ms/step - loss: 1.6886e-06 - val_loss: 5.1540e-06
# Epoch 138/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.5782e-06 - val_loss: 5.4986e-06
# Epoch 139/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.7431e-06 - val_loss: 5.6266e-06
# Epoch 140/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.7101e-06 - val_loss: 5.5905e-06
# Epoch 141/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.5822e-06 - val_loss: 5.3710e-06
# Epoch 142/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.5465e-06 - val_loss: 5.4318e-06
# Epoch 143/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.6401e-06 - val_loss: 5.6999e-06
# Epoch 144/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.7435e-06 - val_loss: 6.5432e-06
# Epoch 145/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 2.5272e-06 - val_loss: 6.7513e-06
# Epoch 146/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 2.0369e-06 - val_loss: 5.0792e-06
# Epoch 147/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.6274e-06 - val_loss: 5.3136e-06
# Epoch 148/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.6298e-06 - val_loss: 5.7042e-06
# Epoch 149/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.6942e-06 - val_loss: 5.5822e-06
# Epoch 150/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.5696e-06 - val_loss: 5.3237e-06
# Epoch 151/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.5444e-06 - val_loss: 5.1058e-06
# Epoch 152/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.4931e-06 - val_loss: 5.3571e-06
# Epoch 153/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.7370e-06 - val_loss: 5.3229e-06
# Epoch 154/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.8736e-06 - val_loss: 5.8828e-06
# Epoch 155/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.8540e-06 - val_loss: 5.4748e-06
# Epoch 156/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.9014e-06 - val_loss: 5.7022e-06
# Epoch 157/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.7651e-06 - val_loss: 5.4542e-06
# Epoch 158/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.6655e-06 - val_loss: 5.1099e-06
# Epoch 159/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.7112e-06 - val_loss: 5.1165e-06
# Epoch 160/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.5110e-06 - val_loss: 5.3429e-06
# Epoch 161/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.6555e-06 - val_loss: 5.0921e-06
# Epoch 162/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.5779e-06 - val_loss: 5.4283e-06
# Epoch 163/2000
# 11/11 [==============================] - 4s 371ms/step - loss: 1.6088e-06 - val_loss: 5.5496e-06
# Epoch 164/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.5971e-06 - val_loss: 5.3568e-06
# Epoch 165/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.5097e-06 - val_loss: 5.1909e-06
# Epoch 166/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.4968e-06 - val_loss: 5.1706e-06
# Epoch 167/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.4834e-06 - val_loss: 5.1136e-06
# Epoch 168/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.7964e-06 - val_loss: 5.5543e-06
# Epoch 169/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.7695e-06 - val_loss: 5.6751e-06
# Epoch 170/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.6801e-06 - val_loss: 5.6042e-06
# Epoch 171/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.6222e-06 - val_loss: 5.1257e-06
# Epoch 172/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.4990e-06 - val_loss: 5.3049e-06
# Epoch 173/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.4835e-06 - val_loss: 5.1504e-06
# Epoch 174/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.4673e-06 - val_loss: 5.3013e-06
# Epoch 175/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4861e-06 - val_loss: 5.2644e-06
# Epoch 176/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.4598e-06 - val_loss: 5.1469e-06
# Epoch 177/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.5407e-06 - val_loss: 5.1232e-06
# Epoch 178/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.5624e-06 - val_loss: 5.3782e-06
# Epoch 179/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.4611e-06 - val_loss: 5.2001e-06
# Epoch 180/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.6307e-06 - val_loss: 5.2153e-06
# Epoch 181/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.5598e-06 - val_loss: 5.1947e-06
# Epoch 182/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.4878e-06 - val_loss: 5.3150e-06
# Epoch 183/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.4627e-06 - val_loss: 5.3979e-06
# Epoch 184/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.4977e-06 - val_loss: 6.2474e-06
# Epoch 185/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.8291e-06 - val_loss: 5.3235e-06
# Epoch 186/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.6999e-06 - val_loss: 5.3432e-06
# Epoch 187/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.6515e-06 - val_loss: 5.0578e-06
# Epoch 188/2000
# 11/11 [==============================] - 4s 370ms/step - loss: 1.6059e-06 - val_loss: 5.6004e-06
# Epoch 189/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.5491e-06 - val_loss: 5.3029e-06
# Epoch 190/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.7261e-06 - val_loss: 5.3211e-06
# Epoch 191/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4956e-06 - val_loss: 5.1636e-06
# Epoch 192/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.4669e-06 - val_loss: 5.2241e-06
# Epoch 193/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.4527e-06 - val_loss: 5.3546e-06
# Epoch 194/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.4651e-06 - val_loss: 5.1874e-06
# Epoch 195/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.4782e-06 - val_loss: 5.2910e-06
# Epoch 196/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.5059e-06 - val_loss: 5.2107e-06
# Epoch 197/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.4561e-06 - val_loss: 5.2023e-06
# Epoch 198/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.5022e-06 - val_loss: 5.4074e-06
# Epoch 199/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4637e-06 - val_loss: 5.2802e-06
# Epoch 200/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4516e-06 - val_loss: 5.2851e-06
# Epoch 201/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.5922e-06 - val_loss: 5.3653e-06
# Epoch 202/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.7084e-06 - val_loss: 5.5394e-06
# Epoch 203/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.7177e-06 - val_loss: 6.2776e-06
# Epoch 204/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.6524e-06 - val_loss: 5.1525e-06
# Epoch 205/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.4404e-06 - val_loss: 5.3337e-06
# Epoch 206/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.4161e-06 - val_loss: 5.3160e-06
# Epoch 207/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4136e-06 - val_loss: 5.3858e-06
# Epoch 208/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.4273e-06 - val_loss: 5.2397e-06
# Epoch 209/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.4939e-06 - val_loss: 5.2616e-06
# Epoch 210/2000
# 11/11 [==============================] - 4s 372ms/step - loss: 1.5981e-06 - val_loss: 5.4622e-06
# Epoch 211/2000
# 11/11 [==============================] - 4s 367ms/step - loss: 1.6489e-06 - val_loss: 5.2691e-06
# Epoch 212/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.4662e-06 - val_loss: 5.3415e-06
# Epoch 213/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.4334e-06 - val_loss: 5.3956e-06
# Epoch 214/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.5022e-06 - val_loss: 5.3509e-06
# Epoch 215/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.6732e-06 - val_loss: 5.6361e-06
# Epoch 216/2000
# 11/11 [==============================] - 4s 344ms/step - loss: 1.5916e-06 - val_loss: 5.2611e-06
# Epoch 217/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4167e-06 - val_loss: 5.3740e-06
# Epoch 218/2000
# 11/11 [==============================] - 4s 371ms/step - loss: 1.4159e-06 - val_loss: 5.2959e-06
# Epoch 219/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4143e-06 - val_loss: 5.7375e-06
# Epoch 220/2000
# 11/11 [==============================] - 4s 343ms/step - loss: 1.6042e-06 - val_loss: 5.2386e-06
# Epoch 221/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.5700e-06 - val_loss: 5.2796e-06
# Epoch 222/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.4557e-06 - val_loss: 5.2805e-06
# Epoch 223/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4404e-06 - val_loss: 5.4505e-06
# Epoch 224/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.4532e-06 - val_loss: 5.5578e-06
# Epoch 225/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.5593e-06 - val_loss: 5.4625e-06
# Epoch 226/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.4384e-06 - val_loss: 5.4227e-06
# Epoch 227/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4540e-06 - val_loss: 5.2243e-06
# Epoch 228/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.3962e-06 - val_loss: 5.5184e-06
# Epoch 229/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.5076e-06 - val_loss: 5.2316e-06
# Epoch 230/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.4633e-06 - val_loss: 5.2934e-06
# Epoch 231/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.4137e-06 - val_loss: 5.3699e-06
# Epoch 232/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.5276e-06 - val_loss: 5.3397e-06
# Epoch 233/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.3993e-06 - val_loss: 5.2075e-06
# Epoch 234/2000
# 11/11 [==============================] - 4s 366ms/step - loss: 1.4030e-06 - val_loss: 5.4613e-06
# Epoch 235/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4091e-06 - val_loss: 5.4266e-06
# Epoch 236/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4318e-06 - val_loss: 5.5440e-06
# Epoch 237/2000
# 11/11 [==============================] - 4s 340ms/step - loss: 1.6238e-06 - val_loss: 5.4688e-06
# Epoch 238/2000
# 11/11 [==============================] - 4s 365ms/step - loss: 1.5973e-06 - val_loss: 5.4133e-06
# Epoch 239/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.5120e-06 - val_loss: 5.2855e-06
# Epoch 240/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.5218e-06 - val_loss: 5.3442e-06
# Epoch 241/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.4770e-06 - val_loss: 5.3700e-06
# Epoch 242/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.4209e-06 - val_loss: 5.5255e-06
# Epoch 243/2000
# 11/11 [==============================] - 4s 345ms/step - loss: 1.4312e-06 - val_loss: 5.4089e-06
# Epoch 244/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.4709e-06 - val_loss: 5.5061e-06
# Epoch 245/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.4164e-06 - val_loss: 5.3243e-06
# Epoch 246/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4046e-06 - val_loss: 5.3218e-06
# Epoch 247/2000
# 11/11 [==============================] - 4s 367ms/step - loss: 1.4331e-06 - val_loss: 5.4752e-06
# Epoch 248/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.4372e-06 - val_loss: 5.6124e-06
# Epoch 249/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.4388e-06 - val_loss: 5.2556e-06
# Epoch 250/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.4279e-06 - val_loss: 5.2532e-06
# Epoch 251/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4009e-06 - val_loss: 5.2876e-06
# Epoch 252/2000
# 11/11 [==============================] - 4s 365ms/step - loss: 1.3705e-06 - val_loss: 5.3490e-06
# Epoch 253/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.3720e-06 - val_loss: 5.3944e-06
# Epoch 254/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4873e-06 - val_loss: 5.3321e-06
# Epoch 255/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4730e-06 - val_loss: 5.5791e-06
# Epoch 256/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.6635e-06 - val_loss: 5.6215e-06
# Epoch 257/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.5197e-06 - val_loss: 5.6564e-06
# Epoch 258/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.6329e-06 - val_loss: 5.1313e-06
# Epoch 259/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.3742e-06 - val_loss: 5.2520e-06
# Epoch 260/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4027e-06 - val_loss: 5.3333e-06
# Epoch 261/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4069e-06 - val_loss: 5.7031e-06
# Epoch 262/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.5130e-06 - val_loss: 5.3317e-06
# Epoch 263/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.4018e-06 - val_loss: 5.3804e-06
# Epoch 264/2000
# 11/11 [==============================] - 4s 347ms/step - loss: 1.4519e-06 - val_loss: 5.3579e-06
# Epoch 265/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.4168e-06 - val_loss: 5.3344e-06
# Epoch 266/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.4104e-06 - val_loss: 5.4354e-06
# Epoch 267/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.3679e-06 - val_loss: 5.2429e-06
# Epoch 268/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3931e-06 - val_loss: 5.4453e-06
# Epoch 269/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.5223e-06 - val_loss: 5.4211e-06
# Epoch 270/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.4175e-06 - val_loss: 5.2852e-06
# Epoch 271/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.3557e-06 - val_loss: 5.2069e-06
# Epoch 272/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4161e-06 - val_loss: 5.7618e-06
# Epoch 273/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.4760e-06 - val_loss: 5.2288e-06
# Epoch 274/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.3636e-06 - val_loss: 5.4128e-06
# Epoch 275/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.5084e-06 - val_loss: 5.5426e-06
# Epoch 276/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.6694e-06 - val_loss: 5.6954e-06
# Epoch 277/2000
# 11/11 [==============================] - 4s 347ms/step - loss: 1.5191e-06 - val_loss: 5.5068e-06
# Epoch 278/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.3749e-06 - val_loss: 5.2015e-06
# Epoch 279/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.4103e-06 - val_loss: 5.3448e-06
# Epoch 280/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.5777e-06 - val_loss: 5.9318e-06
# Epoch 281/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.5091e-06 - val_loss: 5.2513e-06
# Epoch 282/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.4281e-06 - val_loss: 5.4803e-06
# Epoch 283/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4696e-06 - val_loss: 5.4481e-06
# Epoch 284/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.4491e-06 - val_loss: 5.0619e-06
# Epoch 285/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.5038e-06 - val_loss: 5.5062e-06
# Epoch 286/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.3706e-06 - val_loss: 5.0767e-06
# Epoch 287/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.4313e-06 - val_loss: 5.5184e-06
# Epoch 288/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.3938e-06 - val_loss: 5.4615e-06
# Epoch 289/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.4973e-06 - val_loss: 5.4079e-06
# Epoch 290/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.5614e-06 - val_loss: 5.7490e-06
# Epoch 291/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.5260e-06 - val_loss: 5.1236e-06
# Epoch 292/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.3638e-06 - val_loss: 5.3122e-06
# Epoch 293/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.3475e-06 - val_loss: 5.2934e-06
# Epoch 294/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4004e-06 - val_loss: 5.4655e-06
# Epoch 295/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4117e-06 - val_loss: 5.2821e-06
# Epoch 296/2000
# 11/11 [==============================] - 4s 368ms/step - loss: 1.3728e-06 - val_loss: 5.2859e-06
# Epoch 297/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.3738e-06 - val_loss: 5.2817e-06
# Epoch 298/2000
# 11/11 [==============================] - 4s 369ms/step - loss: 1.4077e-06 - val_loss: 5.3705e-06
# Epoch 299/2000
# 11/11 [==============================] - 4s 368ms/step - loss: 1.4110e-06 - val_loss: 5.3886e-06
# Epoch 300/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3927e-06 - val_loss: 5.4375e-06
# Epoch 301/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.4501e-06 - val_loss: 5.7203e-06
# Epoch 302/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.3912e-06 - val_loss: 5.2085e-06
# Epoch 303/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.3896e-06 - val_loss: 5.2846e-06
# Epoch 304/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.4552e-06 - val_loss: 5.6465e-06
# Epoch 305/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.6214e-06 - val_loss: 5.2580e-06
# Epoch 306/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.5541e-06 - val_loss: 5.3596e-06
# Epoch 307/2000
# 11/11 [==============================] - 4s 347ms/step - loss: 1.4806e-06 - val_loss: 5.2982e-06
# Epoch 308/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4089e-06 - val_loss: 5.4600e-06
# Epoch 309/2000
# 11/11 [==============================] - 4s 366ms/step - loss: 1.4749e-06 - val_loss: 5.0062e-06
# Epoch 310/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3502e-06 - val_loss: 5.3481e-06
# Epoch 311/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.3319e-06 - val_loss: 5.1577e-06
# Epoch 312/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.3437e-06 - val_loss: 5.5084e-06
# Epoch 313/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.3784e-06 - val_loss: 5.3619e-06
# Epoch 314/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.3625e-06 - val_loss: 5.2736e-06
# Epoch 315/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.3674e-06 - val_loss: 5.4002e-06
# Epoch 316/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.3818e-06 - val_loss: 5.6212e-06
# Epoch 317/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.4763e-06 - val_loss: 5.0997e-06
# Epoch 318/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.5113e-06 - val_loss: 5.6693e-06
# Epoch 319/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.3905e-06 - val_loss: 4.9844e-06
# Epoch 320/2000
# 11/11 [==============================] - 4s 344ms/step - loss: 1.3657e-06 - val_loss: 5.6251e-06
# Epoch 321/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3527e-06 - val_loss: 5.0498e-06
# Epoch 322/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.4040e-06 - val_loss: 5.7770e-06
# Epoch 323/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.5336e-06 - val_loss: 5.2944e-06
# Epoch 324/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.3664e-06 - val_loss: 5.1597e-06
# Epoch 325/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4030e-06 - val_loss: 5.3565e-06
# Epoch 326/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.3457e-06 - val_loss: 5.2906e-06
# Epoch 327/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.3392e-06 - val_loss: 5.1421e-06
# Epoch 328/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.3346e-06 - val_loss: 5.1779e-06
# Epoch 329/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3340e-06 - val_loss: 5.3590e-06
# Epoch 330/2000
# 11/11 [==============================] - 4s 366ms/step - loss: 1.3605e-06 - val_loss: 5.3177e-06
# Epoch 331/2000
# 11/11 [==============================] - 4s 371ms/step - loss: 1.3659e-06 - val_loss: 5.3698e-06
# Epoch 332/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.3183e-06 - val_loss: 5.1114e-06
# Epoch 333/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.3524e-06 - val_loss: 5.3214e-06
# Epoch 334/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.4260e-06 - val_loss: 5.4410e-06
# Epoch 335/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.4447e-06 - val_loss: 5.1578e-06
# Epoch 336/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.3671e-06 - val_loss: 5.5201e-06
# Epoch 337/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.3485e-06 - val_loss: 4.9673e-06
# Epoch 338/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.3723e-06 - val_loss: 5.1123e-06
# Epoch 339/2000
# 11/11 [==============================] - 4s 367ms/step - loss: 1.3581e-06 - val_loss: 5.6367e-06
# Epoch 340/2000
# 11/11 [==============================] - 4s 344ms/step - loss: 1.3365e-06 - val_loss: 5.1309e-06
# Epoch 341/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.4189e-06 - val_loss: 5.4728e-06
# Epoch 342/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.6660e-06 - val_loss: 5.2890e-06
# Epoch 343/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.5642e-06 - val_loss: 5.2240e-06
# Epoch 344/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.4175e-06 - val_loss: 5.2546e-06
# Epoch 345/2000
# 11/11 [==============================] - 4s 361ms/step - loss: 1.3313e-06 - val_loss: 5.0459e-06
# Epoch 346/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.3260e-06 - val_loss: 5.4151e-06
# Epoch 347/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3451e-06 - val_loss: 5.0717e-06
# Epoch 348/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.3697e-06 - val_loss: 5.5153e-06
# Epoch 349/2000
# 11/11 [==============================] - 4s 369ms/step - loss: 1.3526e-06 - val_loss: 4.8580e-06
# Epoch 350/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.3972e-06 - val_loss: 5.6877e-06
# Epoch 351/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.3631e-06 - val_loss: 5.1086e-06
# Epoch 352/2000
# 11/11 [==============================] - 4s 342ms/step - loss: 1.3249e-06 - val_loss: 5.3184e-06
# Epoch 353/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.3760e-06 - val_loss: 4.9383e-06
# Epoch 354/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.4539e-06 - val_loss: 5.7669e-06
# Epoch 355/2000
# 11/11 [==============================] - 4s 365ms/step - loss: 1.3733e-06 - val_loss: 5.1034e-06
# Epoch 356/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3398e-06 - val_loss: 5.2340e-06
# Epoch 357/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.3753e-06 - val_loss: 5.4068e-06
# Epoch 358/2000
# 11/11 [==============================] - 4s 343ms/step - loss: 1.4262e-06 - val_loss: 5.2506e-06
# Epoch 359/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.3456e-06 - val_loss: 5.3047e-06
# Epoch 360/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.4102e-06 - val_loss: 5.5508e-06
# Epoch 361/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.4351e-06 - val_loss: 5.0216e-06
# Epoch 362/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.3733e-06 - val_loss: 5.6089e-06
# Epoch 363/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.3294e-06 - val_loss: 4.9212e-06
# Epoch 364/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.4026e-06 - val_loss: 5.2083e-06
# Epoch 365/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.3678e-06 - val_loss: 4.9069e-06
# Epoch 366/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.3878e-06 - val_loss: 5.3863e-06
# Epoch 367/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.4100e-06 - val_loss: 5.4729e-06
# Epoch 368/2000
# 11/11 [==============================] - 4s 347ms/step - loss: 1.4892e-06 - val_loss: 5.3127e-06
# Epoch 369/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.5587e-06 - val_loss: 5.6826e-06
# Epoch 370/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.4733e-06 - val_loss: 4.7156e-06
# Epoch 371/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.3737e-06 - val_loss: 5.4619e-06
# Epoch 372/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.3388e-06 - val_loss: 5.2271e-06
# Epoch 373/2000
# 11/11 [==============================] - 4s 347ms/step - loss: 1.3594e-06 - val_loss: 4.8924e-06
# Epoch 374/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.3214e-06 - val_loss: 5.4260e-06
# Epoch 375/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.3543e-06 - val_loss: 4.9632e-06
# Epoch 376/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.3447e-06 - val_loss: 5.2176e-06
# Epoch 377/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.3565e-06 - val_loss: 5.1449e-06
# Epoch 378/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.3408e-06 - val_loss: 5.1877e-06
# Epoch 379/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.3491e-06 - val_loss: 4.9363e-06
# Epoch 380/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.3924e-06 - val_loss: 5.6025e-06
# Epoch 381/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.3697e-06 - val_loss: 4.9475e-06
# Epoch 382/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.3383e-06 - val_loss: 5.2361e-06
# Epoch 383/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.3566e-06 - val_loss: 5.1046e-06
# Epoch 384/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.3184e-06 - val_loss: 5.4662e-06
# Epoch 385/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.3799e-06 - val_loss: 5.1401e-06
# Epoch 386/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.3534e-06 - val_loss: 5.2766e-06
# Epoch 387/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.3166e-06 - val_loss: 5.0825e-06
# Epoch 388/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.3209e-06 - val_loss: 5.2874e-06
# Epoch 389/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.3417e-06 - val_loss: 5.3766e-06
# Epoch 390/2000
# 11/11 [==============================] - 4s 359ms/step - loss: 1.3213e-06 - val_loss: 4.9944e-06
# Epoch 391/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.2908e-06 - val_loss: 5.4038e-06
# Epoch 392/2000
# 11/11 [==============================] - 4s 353ms/step - loss: 1.3993e-06 - val_loss: 5.0821e-06
# Epoch 393/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4045e-06 - val_loss: 5.3514e-06
# Epoch 394/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.4871e-06 - val_loss: 5.5951e-06
# Epoch 395/2000
# 11/11 [==============================] - 4s 362ms/step - loss: 1.4670e-06 - val_loss: 5.4884e-06
# Epoch 396/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.4353e-06 - val_loss: 5.2168e-06
# Epoch 397/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4013e-06 - val_loss: 5.2523e-06
# Epoch 398/2000
# 11/11 [==============================] - 4s 349ms/step - loss: 1.4322e-06 - val_loss: 4.8927e-06
# Epoch 399/2000
# 11/11 [==============================] - 4s 358ms/step - loss: 1.3413e-06 - val_loss: 5.1924e-06
# Epoch 400/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3196e-06 - val_loss: 5.2945e-06
# Epoch 401/2000
# 11/11 [==============================] - 4s 357ms/step - loss: 1.3034e-06 - val_loss: 5.0248e-06
# Epoch 402/2000
# 11/11 [==============================] - 4s 344ms/step - loss: 1.3353e-06 - val_loss: 5.1486e-06
# Epoch 403/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.3083e-06 - val_loss: 5.1666e-06
# Epoch 404/2000
# 11/11 [==============================] - 4s 345ms/step - loss: 1.3176e-06 - val_loss: 4.9933e-06
# Epoch 405/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4297e-06 - val_loss: 5.2105e-06
# Epoch 406/2000
# 11/11 [==============================] - 4s 352ms/step - loss: 1.3219e-06 - val_loss: 5.3646e-06
# Epoch 407/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.3426e-06 - val_loss: 4.7576e-06
# Epoch 408/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.3793e-06 - val_loss: 5.8135e-06
# Epoch 409/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.4649e-06 - val_loss: 4.8017e-06
# Epoch 410/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.2954e-06 - val_loss: 5.2399e-06
# Epoch 411/2000
# 11/11 [==============================] - 4s 346ms/step - loss: 1.3102e-06 - val_loss: 5.1415e-06
# Epoch 412/2000
# 11/11 [==============================] - 4s 365ms/step - loss: 1.3402e-06 - val_loss: 5.4190e-06
# Epoch 413/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.4693e-06 - val_loss: 4.8317e-06
# Epoch 414/2000
# 11/11 [==============================] - 4s 351ms/step - loss: 1.4794e-06 - val_loss: 5.3655e-06
# Epoch 415/2000
# 11/11 [==============================] - 4s 350ms/step - loss: 1.4571e-06 - val_loss: 5.2344e-06
# Epoch 416/2000
# 11/11 [==============================] - 4s 366ms/step - loss: 1.3745e-06 - val_loss: 5.1815e-06
# Epoch 417/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.4147e-06 - val_loss: 5.3641e-06
# Epoch 418/2000
# 11/11 [==============================] - 4s 363ms/step - loss: 1.4365e-06 - val_loss: 5.0296e-06
# Epoch 419/2000
# 11/11 [==============================] - 4s 356ms/step - loss: 1.2964e-06 - val_loss: 5.3054e-06
# Epoch 420/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.3474e-06 - val_loss: 4.9957e-06
# Epoch 421/2000
# 11/11 [==============================] - 4s 348ms/step - loss: 1.3065e-06 - val_loss: 5.1138e-06
# Epoch 422/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.3373e-06 - val_loss: 5.7153e-06
# Epoch 423/2000
# 11/11 [==============================] - 4s 360ms/step - loss: 1.3557e-06 - val_loss: 5.0866e-06
# Epoch 424/2000
# 11/11 [==============================] - 4s 354ms/step - loss: 1.2861e-06 - val_loss: 5.3494e-06
# Epoch 425/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.3040e-06 - val_loss: 5.1299e-06
# Epoch 426/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.2823e-06 - val_loss: 5.1002e-06
# Epoch 427/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.3402e-06 - val_loss: 5.4073e-06
# Epoch 428/2000
# 11/11 [==============================] - 4s 364ms/step - loss: 1.3457e-06 - val_loss: 5.4507e-06
# Epoch 429/2000
# 11/11 [==============================] - 4s 355ms/step - loss: 1.3197e-06 - val_loss: 5.1244e-06
# Epoch 430/2000
# ...
# Epoch 1860/2000
# 10/10 [==============================] - 4s 353ms/step - loss: 1.9808e-08 - val_loss: 1.5262e-08
# Epoch 1861/2000
# 10/10 [==============================] - 4s 356ms/step - loss: 1.9814e-08 - val_loss: 1.6555e-08
# Epoch 1862/2000
# 10/10 [==============================] - 3s 351ms/step - loss: 2.0251e-08 - val_loss: 2.4724e-08
# Epoch 1863/2000
# 10/10 [==============================] - 4s 350ms/step - loss: 1.8590e-08 - val_loss: 2.0628e-08
# Epoch 1864/2000
# 10/10 [==============================] - 3s 347ms/step - loss: 1.7212e-08 - val_loss: 1.5282e-08
# Epoch 1865/2000
# 10/10 [==============================] - 4s 357ms/step - loss: 1.6232e-08 - val_loss: 1.5055e-08
# Epoch 1866/2000
# 10/10 [==============================] - 4s 364ms/step - loss: 1.6604e-08 - val_loss: 1.5942e-08
# Epoch 1867/2000
# 10/10 [==============================] - 4s 355ms/step - loss: 1.7594e-08 - val_loss: 1.5964e-08
# Epoch 1868/2000
# 10/10 [==============================] - 4s 353ms/step - loss: 1.5576e-08 - val_loss: 1.5412e-08
# Epoch 1869/2000
# 10/10 [==============================] - 3s 346ms/step - loss: 1.5416e-08 - val_loss: 1.4831e-08
# Epoch 1870/2000
# 10/10 [==============================] - 4s 353ms/step - loss: 1.5418e-08 - val_loss: 1.5927e-08
# Epoch 1871/2000
# 10/10 [==============================] - 3s 349ms/step - loss: 1.5979e-08 - val_loss: 2.0277e-08
# Epoch 1872/2000
# 10/10 [==============================] - 4s 363ms/step - loss: 1.9688e-08 - val_loss: 2.1088e-08
# Epoch 1873/2000
# 10/10 [==============================] - 3s 351ms/step - loss: 1.6452e-08 - val_loss: 1.3975e-08
# Epoch 1874/2000
# 10/10 [==============================] - 3s 352ms/step - loss: 1.4285e-08 - val_loss: 3.3672e-08
# Epoch 1875/2000
# 10/10 [==============================] - 4s 360ms/step - loss: 1.2873e-07 - val_loss: 7.2692e-08
# Epoch 1876/2000
# 10/10 [==============================] - 4s 364ms/step - loss: 4.7548e-08 - val_loss: 5.9553e-08
# Epoch 1877/2000
# 10/10 [==============================] - 4s 353ms/step - loss: 3.4308e-08 - val_loss: 2.0393e-08
# Epoch 1878/2000
# 10/10 [==============================] - 3s 349ms/step - loss: 2.8149e-08 - val_loss: 1.4705e-08
# Epoch 1879/2000
# 10/10 [==============================] - 3s 344ms/step - loss: 2.0677e-08 - val_loss: 1.4533e-08
# Epoch 1880/2000
# 10/10 [==============================] - 3s 348ms/step - loss: 1.7406e-08 - val_loss: 1.4907e-08
# Epoch 1881/2000
# 10/10 [==============================] - 3s 346ms/step - loss: 2.0127e-08 - val_loss: 2.2092e-08
# Epoch 1882/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 2.1925e-08 - val_loss: 1.8241e-08
# Epoch 1883/2000
# 10/10 [==============================] - 3s 344ms/step - loss: 2.1632e-08 - val_loss: 1.5476e-08
# Epoch 1884/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 2.1690e-08 - val_loss: 1.5420e-08
# Epoch 1885/2000
# 10/10 [==============================] - 4s 364ms/step - loss: 2.1231e-08 - val_loss: 1.5131e-08
# Epoch 1886/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 1.6182e-08 - val_loss: 1.5755e-08
# Epoch 1887/2000
# 10/10 [==============================] - 4s 357ms/step - loss: 1.8884e-08 - val_loss: 1.2467e-08
# Epoch 1888/2000
# 10/10 [==============================] - 4s 365ms/step - loss: 2.5414e-08 - val_loss: 1.5924e-08
# Epoch 1889/2000
# 10/10 [==============================] - 4s 355ms/step - loss: 1.8898e-08 - val_loss: 1.8076e-08
# Epoch 1890/2000
# 10/10 [==============================] - 4s 355ms/step - loss: 1.8588e-08 - val_loss: 1.5923e-08
# Epoch 1891/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 1.4547e-08 - val_loss: 1.4173e-08
# Epoch 1892/2000
# 10/10 [==============================] - 4s 357ms/step - loss: 1.3769e-08 - val_loss: 1.3655e-08
# Epoch 1893/2000
# 10/10 [==============================] - 4s 362ms/step - loss: 1.9445e-08 - val_loss: 2.3933e-08
# Epoch 1894/2000
# 10/10 [==============================] - 4s 357ms/step - loss: 3.8669e-08 - val_loss: 7.3233e-08
# Epoch 1895/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 6.6869e-08 - val_loss: 9.3521e-08
# Epoch 1896/2000
# 10/10 [==============================] - 4s 371ms/step - loss: 4.1585e-08 - val_loss: 3.0748e-08
# Epoch 1897/2000
# 10/10 [==============================] - 4s 352ms/step - loss: 1.9563e-08 - val_loss: 1.6911e-08
# Epoch 1898/2000
# 10/10 [==============================] - 4s 366ms/step - loss: 1.6153e-08 - val_loss: 2.2417e-08
# Epoch 1899/2000
# 10/10 [==============================] - 4s 354ms/step - loss: 1.6315e-08 - val_loss: 1.5106e-08
# Epoch 1900/2000
# 10/10 [==============================] - 3s 346ms/step - loss: 1.5185e-08 - val_loss: 1.6293e-08
# Epoch 1901/2000
# 10/10 [==============================] - 4s 357ms/step - loss: 1.4914e-08 - val_loss: 1.6764e-08
# Epoch 1902/2000
# 10/10 [==============================] - 4s 371ms/step - loss: 1.5561e-08 - val_loss: 4.2446e-08
# Epoch 1903/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 3.4295e-08 - val_loss: 2.7402e-08
# Epoch 1904/2000
# 10/10 [==============================] - 4s 351ms/step - loss: 2.0699e-08 - val_loss: 1.9825e-08
# Epoch 1905/2000
# 10/10 [==============================] - 4s 354ms/step - loss: 2.5289e-08 - val_loss: 5.2434e-08
# Epoch 1906/2000
# 10/10 [==============================] - 4s 356ms/step - loss: 2.8790e-08 - val_loss: 2.0996e-08
# Epoch 1907/2000
# 10/10 [==============================] - 4s 353ms/step - loss: 1.4935e-08 - val_loss: 1.4676e-08
# Epoch 1908/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 1.3641e-08 - val_loss: 2.8038e-08
# Epoch 1909/2000
# 10/10 [==============================] - 4s 369ms/step - loss: 1.2709e-07 - val_loss: 7.2767e-08
# Epoch 1910/2000
# 10/10 [==============================] - 4s 352ms/step - loss: 5.0144e-08 - val_loss: 6.1606e-08
# Epoch 1911/2000
# 10/10 [==============================] - 4s 367ms/step - loss: 3.7885e-08 - val_loss: 2.6094e-08
# Epoch 1912/2000
# 10/10 [==============================] - 4s 366ms/step - loss: 2.6012e-08 - val_loss: 1.6493e-08
# Epoch 1913/2000
# 10/10 [==============================] - 4s 362ms/step - loss: 1.9253e-08 - val_loss: 1.5302e-08
# Epoch 1914/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 1.6136e-08 - val_loss: 1.4070e-08
# Epoch 1915/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 1.5106e-08 - val_loss: 1.5714e-08
# Epoch 1916/2000
# 10/10 [==============================] - 4s 354ms/step - loss: 1.4566e-08 - val_loss: 1.3291e-08
# Epoch 1917/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 1.3474e-08 - val_loss: 1.2643e-08
# Epoch 1918/2000
# 10/10 [==============================] - 4s 362ms/step - loss: 1.3495e-08 - val_loss: 2.6151e-08
# Epoch 1919/2000
# 10/10 [==============================] - 4s 357ms/step - loss: 1.6481e-08 - val_loss: 1.5499e-08
# Epoch 1920/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 1.2369e-08 - val_loss: 1.4793e-08
# Epoch 1921/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 1.5319e-08 - val_loss: 5.6673e-08
# Epoch 1922/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 8.9870e-08 - val_loss: 1.9977e-08
# Epoch 1923/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 4.0701e-08 - val_loss: 2.9842e-08
# Epoch 1924/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 3.1864e-08 - val_loss: 3.8309e-08
# Epoch 1925/2000
# 10/10 [==============================] - 4s 356ms/step - loss: 3.0417e-08 - val_loss: 1.3155e-08
# Epoch 1926/2000
# 10/10 [==============================] - 4s 356ms/step - loss: 2.4673e-08 - val_loss: 1.7731e-08
# Epoch 1927/2000
# 10/10 [==============================] - 4s 360ms/step - loss: 1.6844e-08 - val_loss: 1.9738e-08
# Epoch 1928/2000
# 10/10 [==============================] - 3s 352ms/step - loss: 1.3592e-08 - val_loss: 1.3902e-08
# Epoch 1929/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 1.2422e-08 - val_loss: 1.3998e-08
# Epoch 1930/2000
# 10/10 [==============================] - 4s 363ms/step - loss: 1.1435e-08 - val_loss: 1.3894e-08
# Epoch 1931/2000
# 10/10 [==============================] - 4s 366ms/step - loss: 1.0862e-08 - val_loss: 1.5291e-08
# Epoch 1932/2000
# 10/10 [==============================] - 4s 351ms/step - loss: 1.0217e-08 - val_loss: 1.3454e-08
# Epoch 1933/2000
# 10/10 [==============================] - 4s 362ms/step - loss: 1.3578e-08 - val_loss: 6.3627e-08
# Epoch 1934/2000
# 10/10 [==============================] - 3s 351ms/step - loss: 9.9243e-08 - val_loss: 4.1113e-08
# Epoch 1935/2000
# 10/10 [==============================] - 4s 355ms/step - loss: 2.5592e-08 - val_loss: 2.6505e-08
# Epoch 1936/2000
# 10/10 [==============================] - 4s 353ms/step - loss: 1.6617e-08 - val_loss: 2.0824e-08
# Epoch 1937/2000
# 10/10 [==============================] - 4s 360ms/step - loss: 1.6699e-08 - val_loss: 1.3187e-08
# Epoch 1938/2000
# 10/10 [==============================] - 4s 362ms/step - loss: 1.5724e-08 - val_loss: 1.4276e-08
# Epoch 1939/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 1.2502e-08 - val_loss: 1.5704e-08
# Epoch 1940/2000
# 10/10 [==============================] - 4s 366ms/step - loss: 1.0806e-08 - val_loss: 1.4381e-08
# Epoch 1941/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 1.2052e-08 - val_loss: 1.7505e-08
# Epoch 1942/2000
# 10/10 [==============================] - 4s 356ms/step - loss: 1.2761e-08 - val_loss: 3.3448e-08
# Epoch 1943/2000
# 10/10 [==============================] - 4s 357ms/step - loss: 1.2234e-08 - val_loss: 1.9446e-08
# Epoch 1944/2000
# 10/10 [==============================] - 3s 352ms/step - loss: 9.3844e-09 - val_loss: 1.7839e-08
# Epoch 1945/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 2.7817e-08 - val_loss: 1.9569e-07
# Epoch 1946/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 1.7914e-07 - val_loss: 1.5430e-08
# Epoch 1947/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 5.2591e-08 - val_loss: 3.6979e-08
# Epoch 1948/2000
# 10/10 [==============================] - 4s 354ms/step - loss: 2.6131e-08 - val_loss: 1.5157e-08
# Epoch 1949/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 1.5231e-08 - val_loss: 1.3672e-08
# Epoch 1950/2000
# 10/10 [==============================] - 4s 356ms/step - loss: 1.1787e-08 - val_loss: 1.3739e-08
# Epoch 1951/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 1.1139e-08 - val_loss: 1.3349e-08
# Epoch 1952/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 1.0670e-08 - val_loss: 1.4990e-08
# Epoch 1953/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 9.4278e-09 - val_loss: 1.6284e-08
# Epoch 1954/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 8.1431e-09 - val_loss: 1.9452e-08
# Epoch 1955/2000
# 10/10 [==============================] - 4s 354ms/step - loss: 7.6711e-09 - val_loss: 1.7000e-08
# Epoch 1956/2000
# 10/10 [==============================] - 4s 363ms/step - loss: 7.6032e-09 - val_loss: 2.5321e-08
# Epoch 1957/2000
# 10/10 [==============================] - 3s 343ms/step - loss: 6.7753e-09 - val_loss: 1.8533e-08
# Epoch 1958/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 1.4792e-08 - val_loss: 4.8890e-08
# Epoch 1959/2000
# 10/10 [==============================] - 4s 360ms/step - loss: 9.0444e-09 - val_loss: 2.2881e-08
# Epoch 1960/2000
# 10/10 [==============================] - 4s 381ms/step - loss: 6.0066e-09 - val_loss: 2.7522e-08
# Epoch 1961/2000
# 10/10 [==============================] - 3s 350ms/step - loss: 5.8635e-09 - val_loss: 2.6869e-08
# Epoch 1962/2000
# 10/10 [==============================] - 4s 356ms/step - loss: 6.5259e-08 - val_loss: 5.0513e-07
# Epoch 1963/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 1.4992e-07 - val_loss: 1.4033e-07
# Epoch 1964/2000
# 10/10 [==============================] - 3s 347ms/step - loss: 5.5194e-08 - val_loss: 3.1922e-08
# Epoch 1965/2000
# 10/10 [==============================] - 4s 363ms/step - loss: 1.8712e-08 - val_loss: 1.7353e-08
# Epoch 1966/2000
# 10/10 [==============================] - 4s 365ms/step - loss: 1.1578e-08 - val_loss: 1.7075e-08
# Epoch 1967/2000
# 10/10 [==============================] - 4s 351ms/step - loss: 8.7365e-09 - val_loss: 1.7594e-08
# Epoch 1968/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 6.8644e-09 - val_loss: 2.0708e-08
# Epoch 1969/2000
# 10/10 [==============================] - 4s 355ms/step - loss: 6.0667e-09 - val_loss: 2.1505e-08
# Epoch 1970/2000
# 10/10 [==============================] - 4s 363ms/step - loss: 5.8570e-09 - val_loss: 2.9435e-08
# Epoch 1971/2000
# 10/10 [==============================] - 4s 354ms/step - loss: 6.2093e-09 - val_loss: 3.3673e-08
# Epoch 1972/2000
# 10/10 [==============================] - 4s 370ms/step - loss: 1.8368e-08 - val_loss: 1.7819e-07
# Epoch 1973/2000
# 10/10 [==============================] - 4s 352ms/step - loss: 5.6930e-08 - val_loss: 2.8095e-08
# Epoch 1974/2000
# 10/10 [==============================] - 4s 356ms/step - loss: 2.2123e-08 - val_loss: 2.3421e-08
# Epoch 1975/2000
# 10/10 [==============================] - 3s 350ms/step - loss: 1.7203e-08 - val_loss: 1.8329e-08
# Epoch 1976/2000
# 10/10 [==============================] - 3s 346ms/step - loss: 1.1507e-08 - val_loss: 1.4887e-08
# Epoch 1977/2000
# 10/10 [==============================] - 3s 346ms/step - loss: 7.9488e-09 - val_loss: 1.7528e-08
# Epoch 1978/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 7.0871e-09 - val_loss: 2.1466e-08
# Epoch 1979/2000
# 10/10 [==============================] - 4s 363ms/step - loss: 5.6225e-09 - val_loss: 2.2983e-08
# Epoch 1980/2000
# 10/10 [==============================] - 4s 362ms/step - loss: 4.9290e-09 - val_loss: 2.3478e-08
# Epoch 1981/2000
# 10/10 [==============================] - 4s 369ms/step - loss: 4.6728e-09 - val_loss: 3.1366e-08
# Epoch 1982/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 4.0024e-09 - val_loss: 2.7319e-08
# Epoch 1983/2000
# 10/10 [==============================] - 4s 355ms/step - loss: 3.6956e-09 - val_loss: 3.2527e-08
# Epoch 1984/2000
# 10/10 [==============================] - 3s 347ms/step - loss: 8.6027e-09 - val_loss: 1.3736e-07
# Epoch 1985/2000
# 10/10 [==============================] - 4s 353ms/step - loss: 3.5143e-07 - val_loss: 2.6776e-07
# Epoch 1986/2000
# 10/10 [==============================] - 4s 353ms/step - loss: 1.7329e-07 - val_loss: 2.4096e-08
# Epoch 1987/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 5.8783e-08 - val_loss: 5.6570e-08
# Epoch 1988/2000
# 10/10 [==============================] - 4s 363ms/step - loss: 3.3403e-08 - val_loss: 2.8188e-08
# Epoch 1989/2000
# 10/10 [==============================] - 4s 359ms/step - loss: 2.1092e-08 - val_loss: 1.7559e-08
# Epoch 1990/2000
# 10/10 [==============================] - 4s 357ms/step - loss: 1.5695e-08 - val_loss: 1.5344e-08
# Epoch 1991/2000
# 10/10 [==============================] - 4s 354ms/step - loss: 1.3420e-08 - val_loss: 1.7778e-08
# Epoch 1992/2000
# 10/10 [==============================] - 4s 360ms/step - loss: 1.1803e-08 - val_loss: 1.4171e-08
# Epoch 1993/2000
# 10/10 [==============================] - 3s 351ms/step - loss: 1.0756e-08 - val_loss: 1.4905e-08
# Epoch 1994/2000
# 10/10 [==============================] - 4s 368ms/step - loss: 9.8506e-09 - val_loss: 1.5393e-08
# Epoch 1995/2000
# 10/10 [==============================] - 4s 352ms/step - loss: 8.9734e-09 - val_loss: 1.6355e-08
# Epoch 1996/2000
# 10/10 [==============================] - 4s 364ms/step - loss: 8.4309e-09 - val_loss: 1.6639e-08
# Epoch 1997/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 7.9766e-09 - val_loss: 1.7897e-08
# Epoch 1998/2000
# 10/10 [==============================] - 4s 361ms/step - loss: 7.2966e-09 - val_loss: 1.8959e-08
# Epoch 1999/2000
# 10/10 [==============================] - 4s 358ms/step - loss: 6.4092e-09 - val_loss: 1.9783e-08
# Epoch 2000/2000
# 10/10 [==============================] - 3s 351ms/step - loss: 5.9124e-09 - val_loss: 2.0722e-08

# %%
from calendar import EPOCH

model.load_weights(file_path)
prediction = model.predict(Ex_test)
Realprediction=Lowprediction + prediction
y_graph = savedata_cap_test
prediction_graph = flatten_2Dto1D(Realprediction)
print(prediction_graph.shape)
print(y_graph.shape)
    

print(save_path)
# Out:
# 323/323 [==============================] - 14s 44ms/step
# (10319, 1)
# (10625, 1)
# picture\propecer\3\2000EP

# %%
Error_rate = []
Error = []
y_graph = y_test
for step in range(len(prediction_graph)):
        # Error_rate.append((prediction_graph[step] - savedata_cap_test[step]) / savedata_cap_test[step] * 100)
        Error_rate.append((prediction_graph[step] - y_graph[step]) )
        Error.append(Error_rate[step] / 100)
    
RMSE_total = np.sqrt(np.mean(np.square(Error)))
MAE_total = np.mean(np.absolute(Error))
pl.figure(dpi=150)
line = pl.plot(Error_rate)
pl.ylim(-10, 10)
pl.ylabel('SOC Error (%)')
pl.xlabel('time(s)')
pl.setp(line, color='b', linewidth=0.5)
EP=param['num_epochs']
pl.savefig(f'{save_path}\{Fsize}RMSE{RMSE_total:.6f}MAE{MAE_total:.6f}.png')
pl.show()
print(f'RMSE({RMSE_total:.6f}), MAE({MAE_total:.6f})')
# Out:
# RMSE(0.001417), MAE(0.001390)

# %%
pl.figure(dpi=500)
pl.ylabel('SOC(%)')
pl.xlabel('Time(s)')
line = pl.plot(prediction_graph, label = 'SOC Estimation')
pl.setp(line, linewidth=0.5)

y_line = pl.plot(y_graph, label = 'SOC Reference')
# y_line = pl.plot(y_graph, label = 'Voltage Reference')
pl.setp(y_line, linewidth=0.5)
pl.legend()
pl.savefig(f'{save_path}\{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}.png')
pl.show()
print(prediction_graph.shape)
print(y_graph.shape)
# Out:
# (10319, 1)
# (10319, 1)

# %%
# model = models.Sequential()
# # model.add(layers.Conv1D(param['num_filters'], param['window'], padding='causal', input_shape = (None, x_train00.shape[-1])))
# model.add(layers.LSTM(param['num_units'], return_sequences = True, input_shape = (None, x_train00.shape[-1])))
# # BatchNormalization()
# model.add(layers.LSTM(16))
# # BatchNormalization()
# model.add(layers.Dense(param['num_dense']))
# # BatchNormalization()
# model.add(layers.Dense(1))
# model.compile(loss = 'mse', optimizer = 'Adam') 
# model.summary()

# model2 = models.Sequential()
# # model.add(layers.Conv1D(param['num_filters'], param['window'], padding='causal', input_shape = (None, x_train00.shape[-1])))
# model2.add(layers.LSTM(param['num_units'], return_sequences = True, input_shape = (None, x_train00.shape[-1])))
# # BatchNormalization()
# model2.add(layers.LSTM(16))
# # BatchNormalization()
# model2.add(layers.Dense(param['num_dense']))
# # BatchNormalization()
# model2.add(layers.Dense(1))
# model2.compile(loss = 'mse', optimizer = 'Adam') 
# model2.summary()
# EP=0
# for i in range(0,25):
#     EP=EP+param["num_epochs"]
#     callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True),
#                  TensorBoard(log_dir=log_dir, histogram_freq=hist_freq)]
#     fitdata = model.fit(x_train00, y_train00, epochs=EP, verbose = 0, validation_split = 0.2, callbacks=callback_list,batch_size=param['batch'])
#     callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True),
#                  TensorBoard(log_dir=log_dir, histogram_freq=hist_freq)]
#     fitdata = model.fit(x_train01, y_train01, epochs=EP, verbose = 0, validation_split = 0.2, callbacks=callback_list,batch_size=param['batch'])
    
#     model.load_weights(file_path)
#     prediction = model.predict(x_test)

#     Lowprediction=prediction
    
#     callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True),
#                       TensorBoard(log_dir=log_dir, histogram_freq=hist_freq)]
#     fitdata = model2.fit(Ex_train00, Ey_train00, epochs=EP, verbose = 0, validation_split = 0.2, callbacks=callback_list,batch_size=param['batch'])
#     callback_list = [ModelCheckpoint(filepath = file_path, monitor = 'val_loss', save_best_only = True),
#                      TensorBoard(log_dir=log_dir, histogram_freq=hist_freq)]
#     fitdata = model2.fit(Ex_train01, Ey_train01, epochs=EP, verbose = 0, validation_split = 0.2, callbacks=callback_list,batch_size=param['batch'])

#     from calendar import EPOCH

#     model.load_weights(file_path)
#     prediction = model.predict(Ex_test)
#     Realprediction=Lowprediction + prediction-plus
#     y_graph = y_test
#     prediction_graph = flatten_2Dto1D(Realprediction)

#     Error_rate = []
#     Error = []

#     for step in range(len(prediction_graph)):
#          # Error_rate.append((prediction_graph[step] - savedata_cap_test[step]) / savedata_cap_test[step] * 100)
#          Error_rate.append((prediction_graph[step] - y_graph[step]) / y_graph[step] * 100)
#          Error.append(Error_rate[step] / 100)
    

#     RMSE_total = np.sqrt(np.mean(np.square(Error)))
#     MAE_total = np.mean(np.absolute(Error))
#     pl.figure(dpi=150)
#     line = pl.plot(Error_rate)
#     pl.ylim(-10, 10)
#     pl.ylabel('SOC Error (%)')
#     pl.xlabel('time(s)')
#     pl.setp(line, color='b', linewidth=0.5)
#     pl.savefig(f'{save_path}\Epoch {EP} RMSE {RMSE_total:.6f},MAE {MAE_total:.6f}.png')
#     pl.show()
#     print(f'RMSE({RMSE_total:.6f}), MAE({MAE_total:.6f})')
#     pl.figure(dpi=500)
#     pl.ylabel('Voltage')
#     pl.xlabel('Time(s)')
#     line = pl.plot(prediction_graph, label = 'Voltage Estimation')
#     pl.setp(line, linewidth=0.5)

#     # y_line = pl.plot(savedata_cap_test, label = 'Voltage Reference')
#     y_line = pl.plot(y_graph, label = 'Voltage Reference')
#     pl.setp(y_line, linewidth=0.5)
#     pl.legend()
#     pl.savefig(f'{save_path}\ESTI Epoch {EP} RMSE {RMSE_total:.6f},MAE {MAE_total:.6f}.png')
#     pl.show()
